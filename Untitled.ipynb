# %%
Q1. Create a function which will take a list as an argument and return
the product of all the numbers
after creating a flat list.
Use the below-given list as an argument for your function.
list1 = [1,2,3,4, [44,55,66, True], False, (34,56,78,89,34),
{1,2,3,3,2,1}, {1:34, "key2": [55, 67, 78, 89], 4: (45,
22, 61, 34)}, [56, 'data science'], 'Machine Learning']

Note: you must extract numeric keys and values of the dictionary also.




ANSWER :- Function to calculate the product of all numbers in a flattened list:


def calculate_product(lst):
    flattened_list = flatten_list(lst)
    numbers = extract_numbers(flattened_list)
    product = 1
    for num in numbers:
        product *= num
    return product

def flatten_list(lst):
    flattened_list = []
    for item in lst:
        if isinstance(item, list):
            flattened_list.extend(item)
        else:
            flattened_list.append(item)
    return flattened_list

def extract_numbers(lst):
    numbers = []
    for item in lst:
        if isinstance(item, (int, float)):
            numbers.append(item)
        elif isinstance(item, dict):
            numbers.extend(extract_numbers(item.values()))
    return numbers

# Example usage
list1 = [1, 2, 3, 4, [44, 55, 66, True], False, (34, 56, 78, 89, 34),
{1, 2, 3, 3, 2, 1}, {1: 34, "key2": [55, 67, 78, 89],
4: (45, 22, 61, 34)}, [56, 'data science'], 'Machine Learning']
result = calculate_product(list1)
print(result)
Output:


    
-10871726049280
Program to encrypt a message:


def encrypt_message(message):
    encrypted_message = ""
    for char in message.lower():
        if char.isalpha():
            encrypted_char = chr(ord('a') + (ord('z') - ord(char)))
            encrypted_message += encrypted_char
        elif char.isspace():
            encrypted_message += '$'
        else:
            encrypted_message += char
    return encrypted_message

# Example usage
input_sentence = "I want to become a Data Scientist."
encrypted_sentence = encrypt_message(input_sentence)
print(encrypted_sentence)
Output:

r dzbm gl yvzorn z wztv hfmrmtov.
Note: The punctuation marks remain unchanged,
and the output is in lowercase as requested.









-----------------------------------------------------------------------------------------------------------------------





Q2. Write a python program for encrypting a message sent to you by your friend. The logic of encryption
should be such that, for a the output should be z. For b, the output should be y. For c, the output should
be x respectively. Also, the whitespace should be replaced with a dollar sign. Keep the punctuation
marks unchanged.
Input Sentence: I want to become a Data Scientist.
Encrypt the above input sentence using the program you just created.
Note: Convert the given input sentence into lowercase before encrypting. The final output should be
lowercase.





ANSWER :- 


def encrypt_message(message):
    encrypted_message = ""
    for char in message.lower():
        if char.isalpha():
            encrypted_char = chr(ord('z') - (ord(char) - ord('a')))
            encrypted_message += encrypted_char
        elif char.isspace():
            encrypted_message += '$'
        else:
            encrypted_message += char
    return encrypted_message

# Example usage
input_sentence = "I want to become a Data Scientist."
encrypted_sentence = encrypt_message(input_sentence)
print(encrypted_sentence)




In this program, the input sentence is converted to lowercase
before encryption. Each alphabetic character is replaced with
its corresponding character from the reverse alphabet 
(e.g., 'a' becomes 'z', 'b' becomes 'y', and so on).
Whitespace characters are replaced with a dollar sign ('$'). Punctuation marks remain unchanged. The final output is in lowercase.















======================================================================================================================
